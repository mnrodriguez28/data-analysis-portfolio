# %% [markdown]
# # Contactos al Sistema Único de Atención Ciudadana por Arbolado y Espacios Verdes (2017 - 2021)

# %% [markdown]
# El Sistema Único de Atención Ciudadana (SUACI) permite a los ciudadanos ingresar  reclamos, denuncias, quejas, sugerencias, solicitudes y problemas con los servicios de la Ciudad de Buenos Aires, en este caso, con el servicio de Arbolado y Espacios Verdes.
#
# Los datasets fueron descargados de [data.buenosaires.gob.ar](https://data.buenosaires.gob.ar/dataset/sistema-unico-atencion-ciudadana). Cada dataset tiene mas de 500.000 filas (cada una de ellas representa el contacto de un ciudadano) y 19 columnas que registran: ID del contacto, fecha, categoria y subcategoria del contacto, comuna, barrio, calle, ubicación, género del ciudadano, canal de contacto, entre otras.
#
# A continuación, se presenta el código en Python que fue desarrollado para la limpieza y preparación de los datos para el análisis en Power BI.

# %% [markdown]
# **1. Importación de librerías y carga de datos en Pandas**
#
# En primer lugar, se importó la librería Pandas para el manejo de los datos; y se cargaron los datasets en formato csv con la función `read_csv()`. En algunos casos, los datos estaban separados por `,` y en otros con `;`.

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
data2021 = pd.read_csv("sistema-unico-de-atencion-ciudadana-2021.csv", sep = ";")
data2020 = pd.read_csv("sistema-unico-de-atencion-ciudadana-2020.csv")
data2019 = pd.read_csv("sistema-unico-de-atencion-ciudadana-2019.csv")
data2018 = pd.read_csv("sistema-unico-de-atencion-ciudadana-2018.csv")
data2017 = pd.read_csv("sistema-unico-de-atencion-ciudadana-2017.csv", sep = ";")

# %%
data2021.head(3)
# Out:
#       contacto  periodo               categoria  \
# 0  00173584/21   202104    TRÁMITES Y SERVICIOS
# 1  00173599/21   202104      BARRIOS EMERGENTES
# 2  00173585/21   202104  LIMPIEZA Y RECOLECCIÓN
#
#                             subcategoria  \
# 0  PROPUESTAS PARA LA MEJORA EN TRÁMITES
# 1               SERVICIO DE ELECTRICIDAD
# 2                   RESIDUOS VOLUMINOSOS
#
#                                           prestacion tipo_prestacion  \
# 0              PROPUESTAS PARA LA MEJORA EN TRÁMITES           QUEJA
# 1  CONSULTA DE ESTADO DE EXPEDIENTE ANTE LA AGENC...       SOLICITUD
# 2               RETIRO DE ESCOMBROS / RESTOS DE OBRA        SERVICIO
#
#   fecha_ingreso hora_ingreso  domicilio_comuna domicilio_barrio  \
# 0      13-04-21     11:54:30               NaN              NaN
# 1      13-04-21     12:02:56              10.0       Villa Luro
# 2      13-04-21     11:55:21               2.0         Recoleta
#
#   domiclio_calle  domicilio_altura domicilio_esquina_proxima        lat  \
# 0            NaN               NaN                       NaN        NaN
# 1         MILTON             456.0                       NaN -34.633076
# 2       RIOBAMBA             950.0                       NaN -34.597954
#
#          lon    canal    genero estado_del_contacto fecha_cierre_contacto  \
# 0        NaN  GCS Web  Femenino             Abierto                   NaN
# 1 -58.498882  GCS Web  Femenino             Cerrado   13-04-2021 12:36:18
# 2 -58.394721  GCS Web  Femenino             Cerrado   15-04-2021 13:30:18
#
#   domicilio_calle
# 0             NaN
# 1             NaN
# 2             NaN

# %%
data2020.head(3)
# Out:
#       contacto  periodo                   categoria         subcategoria  \
# 0  00000001/20   202001                    TRÁNSITO        DENUNCIA VIAL
# 1  00000002/20   202001                    TRÁNSITO        DENUNCIA VIAL
# 2  00000003/20   202001  ARBOLADO Y ESPACIOS VERDES  PLANTACIÓN DE ÁRBOL
#
#                    concepto tipo_prestacion fecha_ingreso   hora_ingreso  \
# 0  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2020-01-01  01:09:05 a.m.
# 1  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2020-01-01  01:17:27 a.m.
# 2       PLANTACIÓN DE ÁRBOL       SOLICITUD    2020-01-01  01:17:53 a.m.
#
#   domicilio_cgpc  domicilio_barrio               domicilio_calle  \
# 0       COMUNA 6         CABALLITO  PUEYRREDON, HONORIO, DR. AV.
# 1       COMUNA 4  PARQUE PATRICIOS                   CASEROS AV.
# 2      COMUNA 13        COLEGIALES                         CONDE
#
#    domicilio_altura domicilio_esquina_proxima        lat       long    canal  \
# 0            1070.0                       NaN -34.608243 -58.445167  Comunas
# 1            3223.0                       NaN -34.637739  -58.40965  Comunas
# 2            1014.0                       NaN -34.576143 -58.453507  Comunas
#
#       genero estado_del_contacto fecha_cierre_contacto
# 0   Femenino             Cerrado            2020-01-01
# 1   Femenino             Cerrado            2020-01-01
# 2  Masculino             Cerrado            2020-01-07

# %%
data2019.head(3)
# Out:
#       contacto  periodo                   categoria         subcategoria  \
# 0  00000001/19   201901                    TRÁNSITO        DENUNCIA VIAL
# 1  00000002/19   201901                    TRÁNSITO        DENUNCIA VIAL
# 2  00000003/19   201901  ARBOLADO Y ESPACIOS VERDES  PLANTACIÓN DE ÁRBOL
#
#                    concepto tipo_prestacion fecha_ingreso   hora_ingreso  \
# 0  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  12:11:17 a.m.
# 1  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  12:13:19 a.m.
# 2       PLANTACIÓN DE ÁRBOL       SOLICITUD    2019-01-01  12:23:32 a.m.
#
#   domicilio_cgpc domicilio_barrio  domicilio_calle  domicilio_altura  \
# 0       COMUNA 7           FLORES  BONIFACIO, JOSE            2800.0
# 1       COMUNA 6        CABALLITO  BONIFACIO, JOSE            1108.0
# 2       COMUNA 7           FLORES            MORON            2700.0
#
#   domicilio_esquina_proxima        lat       long    canal    genero  \
# 0                       NaN -34.634060 -58.466561  Comunas  Femenino
# 1                       NaN -34.628159 -58.443377  Comunas  Femenino
# 2                       NaN -34.623319 -58.469811  Comunas  Femenino
#
#   estado_del_contacto fecha_cierre_contacto
# 0             Cerrado            2019-01-02
# 1             Cerrado            2019-01-02
# 2             Cerrado            2019-01-11

# %%
data2018.head(3)
# Out:
#       contacto  periodo categoria   subcategoria                  concepto  \
# 0  00000001/18   201801  TRÁNSITO  DENUNCIA VIAL  VEHÍCULO MAL ESTACIONADO
# 1  00000002/18   201801  TRÁNSITO  DENUNCIA VIAL  VEHÍCULO MAL ESTACIONADO
# 2  00000003/18   201801  TRÁNSITO  DENUNCIA VIAL  VEHÍCULO MAL ESTACIONADO
#
#   tipo_prestacion fecha_ingreso   hora_ingreso domicilio_cgpc  \
# 0        DENUNCIA    2018-01-01  12:03:30 a.m.      COMUNA 13
# 1        DENUNCIA    2018-01-01  12:19:33 a.m.      COMUNA 13
# 2        DENUNCIA    2018-01-01  12:19:33 a.m.      COMUNA 13
#
#   domicilio_barrio     domicilio_calle  domicilio_altura  \
# 0            NUÑEZ      PAZ, GRAL. AV.            1020.0
# 1            NUÑEZ               VEDIA            2225.0
# 2            NUÑEZ  VUELTA DE OBLIGADO            4759.0
#
#   domicilio_esquina_proxima        lat       long canal     genero  \
# 0                       NaN -34.538927 -58.474350   App  masculino
# 1                       NaN -34.539021 -58.473116   App  masculino
# 2                       NaN -34.539686 -58.473425   App  masculino
#
#   estado_del_contacto fecha_cierre_contacto
# 0             Cerrado            2018-01-03
# 1             Cerrado            2018-01-01
# 2             Cerrado            2018-01-03

# %%
data2017.head(3)
# Out:
#       CONTACTO  PERIODO             CATEGORIA          SUBCATEGORIA  \
# 0  00005735/17   201701      CALLES Y VEREDAS  REPARACION DE VEREDA
# 1  00004008/17   201701  MEDIOS DE TRANSPORTE            BICICLETAS
# 2  00004187/17   201701  MEDIOS DE TRANSPORTE            BICICLETAS
#
#                       CONCEPTO TIPO_PRESTACION FECHA_INGRESO  HORA_INGRESO  \
# 0         REPARACION DE VEREDA       SOLICITUD      2/1/2017  5:48:31 p.m.
# 1  INCONVENIENTES CON ECOBICIS           QUEJA      2/1/2017  1:47:51 p.m.
# 2  INCONVENIENTES CON ECOBICIS           QUEJA      2/1/2017  2:08:49 p.m.
#
#   DOMICILIO_CGPC DOMICILIO_BARRIO     DOMICILIO_CALLE  DOMICILIO_ALTURA  \
# 0       COMUNA 5            BOEDO              GIBSON            4192.0
# 1       COMUNA 4             BOCA  GARCIA, MARTIN AV.             364.0
# 2       COMUNA 4             BOCA  GARCIA, MARTIN AV.             364.0
#
#   DOMICILIO_ESQUINA_PROXIMA        LAT      LONG CANAL     GENERO  \
# 0                       NaN -34.638972 -58.42242   WEB   FEMENINO
# 1                       NaN -34.628911 -58.36994   147  MASCULINO
# 2                       NaN -34.628911 -58.36994   147  MASCULINO
#
#   ESTADO_DEL_CONTACTO
# 0             ABIERTO
# 1             ABIERTO
# 2             ABIERTO

# %% [markdown]
# **2. Limpieza y preparación de los datos**

# %% [markdown]
# El siguiente paso fue procesar y preparar los datos para su posterior análisis en Power BI.
#
# Los datasets presentaron algunas diferencias entre sí. Por ejemplo:
#
# - columnas duplicadas (`domicilio_calle`)
# - diferentes nombres para algunas columnas (`prestacion` = `concepto`)
# - diferentes tipo de datos en una misma columna (`domicilio_cgpc`)
# - nombres de las columnas en mayúscula y minúscula

# %%
#eliminar columna duplicada en data2021
data2021 = data2021.drop(["domicilio_calle"], axis = 1)
#cambiar nombre de las columnas en data2021
data2021 = data2021.rename(columns = {"prestacion":"concepto", "domicilio_comuna":"domicilio_cgpc", "domiclio_calle":"domicilio_calle", "lon":"long"})
#cambiar columnas en mayúscula por minúscula en data2017
data2017.columns = data2017.columns.str.lower()
#seleccionar la categoría de ARBOLADO Y ESPACIOS VERDES para cada dataset
data2021 = data2021[data2021["categoria"] == "ARBOLADO Y ESPACIOS VERDES"]
data2020 = data2020[data2020["categoria"] == "ARBOLADO Y ESPACIOS VERDES"]
data2019 = data2019[data2019["categoria"] == "ARBOLADO Y ESPACIOS VERDES"]
data2018 = data2018[data2018["categoria"] == "ARBOLADO Y ESPACIOS VERDES"]
data2017 = data2017[data2017["categoria"] == "ARBOLADO Y ESPACIOS VERDES"]

# %% [markdown]
# Seleccionada la categoría y habiendo realizado algunos preprocesamientos, se unieron los dataframes en uno solo con `concat()` y se seleccionaron las posibles columnas de interés para el análisis. Además, se pasaron los datos de mayúscula a minúscula y se cambió el tipo de dato de la columna `periodo` (str a datetime).

# %%
#unir dataframes
data17_21 = pd.concat([data2017, data2018, data2019, data2020, data2021], ignore_index = True)
#seleccionar columnas
contactos = data17_21[["periodo", "categoria", "subcategoria", "concepto", "tipo_prestacion", "domicilio_cgpc", "domicilio_barrio", "canal", "genero"]]
#cambiar tipo de dato de periodo
contactos["periodo"] = pd.to_datetime(contactos["periodo"], format = "%Y%m")

# %%
#Por último, algunas filas de "domicilio_cgpc" presentan valores distintos a las demás. 
#En vez de "COMUNA 12", por ejemplo, tienen el valor 12.0
contactos.domicilio_cgpc.value_counts().head(15)
# Out:
# COMUNA 11    27368
# COMUNA 9     20043
# COMUNA 10    19818
# COMUNA 12    19505
# COMUNA 15    19169
# COMUNA 7     15877
# COMUNA 13    14604
# COMUNA 4     13353
# COMUNA 8      9481
# COMUNA 14     8656
# COMUNA 6      8409
# COMUNA 5      8129
# 11.0          6915
# 12.0          6880
# COMUNA 3      5540
# Name: domicilio_cgpc, dtype: int64

# %%
#Para solucionar esto, se creó la siguiente función:
def comuna(fila):
    try: #si el valor se puede transformar en int (ya sea float o str)
        return f"COMUNA {int(float(fila))}" #se agrega la palabra COMUNA
    except: #si no se puede transformar, retorna su valor original
        return fila

# %%
#modificar valores de domicilio_cgpc con la función comuna()
contactos["domicilio_cgpc"] = contactos["domicilio_cgpc"].apply(lambda x: comuna(x))
#y cambiamos todo el dataframe en minúscula
contactos = contactos.applymap(lambda x: x.lower() if type(x) == str else x)

# %%
contactos.head()
# Out:
#      periodo                   categoria  \
# 0 2017-01-01  arbolado y espacios verdes
# 1 2017-01-01  arbolado y espacios verdes
# 2 2017-01-01  arbolado y espacios verdes
# 3 2017-01-01  arbolado y espacios verdes
# 4 2017-01-01  arbolado y espacios verdes
#
#                               subcategoria  \
# 0                      extraccion de arbol
# 1  problema con intervenciones de arbolado
# 2  problema con intervenciones de arbolado
# 3                         parques y plazas
# 4     poda de arbol y despeje de luminaria
#
#                                             concepto tipo_prestacion  \
# 0                                extraccion de arbol       solicitud
# 1           problemas con intervenciones de arbolado       solicitud
# 2  falta de recoleccion de restos de poda de arbo...       solicitud
# 3       corte y limpieza de cesped en parque / plaza       solicitud
# 4               poda integral / despeje de luminaria       solicitud
#
#   domicilio_cgpc domicilio_barrio    canal     genero
# 0       comuna 6        caballito      web  masculino
# 1       comuna 5            boedo  comunas   femenino
# 2       comuna 6        caballito      web  masculino
# 3      comuna 15      parque chas      app  masculino
# 4      comuna 15      parque chas      web   femenino

# %%
contactos.tail()
# Out:
#           periodo                   categoria  \
# 250675 2021-10-01  arbolado y espacios verdes
# 250676 2021-10-01  arbolado y espacios verdes
# 250677 2021-10-01  arbolado y espacios verdes
# 250678 2021-10-01  arbolado y espacios verdes
# 250679 2021-10-01  arbolado y espacios verdes
#
#                                 subcategoria  \
# 250675  poda de árbol y despeje de luminaria
# 250676  poda de árbol y despeje de luminaria
# 250677  poda de árbol y despeje de luminaria
# 250678  poda de árbol y despeje de luminaria
# 250679  poda de árbol y despeje de luminaria
#
#                                              concepto tipo_prestacion  \
# 250675  poda de árbol/despeje de luminaria o semáforo       solicitud
# 250676  poda de árbol/despeje de luminaria o semáforo       solicitud
# 250677  poda de árbol/despeje de luminaria o semáforo       solicitud
# 250678  poda de árbol/despeje de luminaria o semáforo       solicitud
# 250679  poda de árbol/despeje de luminaria o semáforo       solicitud
#
#        domicilio_cgpc domicilio_barrio       canal     genero
# 250675      comuna 11     villa devoto  app ba 147  masculino
# 250676       comuna 5          almagro  app ba 147  masculino
# 250677      comuna 14          palermo  app ba 147  masculino
# 250678       comuna 9          liniers  app ba 147  masculino
# 250679      comuna 10     monte castro  app ba 147  masculino

# %% [markdown]
# **3. Guardar en CSV**

# %% [markdown]
# Finalmente, se guardó el dataframe en formato csv con la función de Pandas `to_csv()`.

# %%
contactos.to_csv("contactos_suaci_ba.csv", index = False)

# %% [markdown]
# **4. Transformar datos en Power BI**
#
# El primer paso en Power BI fue transformar algunos datos: se reemplazaron los nombres de aquellos valores que fueron cargados de maneras distintas, por ejemplo `plantacion de arbol` y `plantación de árbol`, `comunas` y `comuna`. Además, a fines prácticos se modificaron y unificaron los nombres de `app ba 147` y `app denuncia vial` por `app`; `call center` y `operador gcba` por `147`; `(en blanco)` por `sin especificar`, entre otros. Luego de este paso, se creó el dashboard.

# %% [markdown]
# **5. Dashboard en Power BI**

# %% [markdown]
# ![image_pbi_01.jpg](attachment:image_pbi_01.jpg)

# %% [markdown]
# ![image_pbi_02.jpg](attachment:image_pbi_02.jpg)

# %% [markdown]
# ![image_pbi_03.jpg](attachment:image_pbi_03.jpg)

# %% [markdown]
# Entre el 2017 y 2021 hubo un total de 250.680 contactos al SUACI por reclamos relacionados con el arbolado y los espacios verdes, siendo el año 2018 con el mayor número de contactos (69.350). El canal más utlizado para realizar las consultas fue el llamado al 147 (seguido del uso de la web y, en tercer lugar, de la app de la Ciudad de Buenos Aires). Más del 90% de los contactos fueron para registrar solicitudes. La subcategoría que más llamados registró fue la poda de árboles para el despeje de luminaria (como postes de luz y semáforos). Por último, la comuna que más contactos realizó fue la Comuna 11 (integrada por lo barrios de Villa General Mitre, Villa Devoto, Villa del Parque y Villa Santa Rita).
